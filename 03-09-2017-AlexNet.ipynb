# %%
import tensorflow as tf

# Load the data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 64
display_step = 20

# Network Parameters
n_input = 784
n_classes = 10
dropout = 0.8

# %%
# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32)

# define weights and biases
weights = {
    'wc1': tf.Variable(tf.random_normal([3, 3, 1, 64])),
    'wc2': tf.Variable(tf.random_normal([3, 3, 64, 128])),
    'wc3': tf.Variable(tf.random_normal([3, 3, 128, 256])),
    'wd1': tf.Variable(tf.random_normal([4*4*256, 1024])),
    'wd2': tf.Variable(tf.random_normal([1024, 1024])),
    'out': tf.Variable(tf.random_normal([1024, 10]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([64])),
    'bc2': tf.Variable(tf.random_normal([128])),
    'bc3': tf.Variable(tf.random_normal([256])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'bd2': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# %%
# define the function

# convolution
def conv2d(name, l_input, w, b):
    return tf.nn.relu(tf.nn.bias_add(tf.nn.conv2d(l_input, w, strides=[1, 1, 1, 1], padding='SAME'), b), name=name)

# maxpooling
def max_pool(name, l_input, k):
    return tf.nn.max_pool(l_input, ksize=[1, k, k, 1], strides=[1, k, k, 1], padding='SAME', name=name)

# normalization
def norm(name, l_input, lsize=4):
    return tf.nn.lrn(l_input, lsize, bias=1.0, alpha=0.001/9.0, beta=0.75, name=name)

# %%
# define Alexnet
def alex_net(_X, _weights, _biases, _dropout):
    # vector transform into matrix
    _X = tf.reshape(_X, shape=[-1, 28, 28, 1])
    # convolution layer1
    conv1 = conv2d('conv1', _X, _weights['wc1'], _biases['bc1'])
    # down sampling layer1
    pool1 = max_pool('pool1', conv1, k=2)
    # normalization layer1
    norm1 = norm('norm1', pool1, lsize=4)
    # Dropout layer1
    norm1 = tf.nn.dropout(norm1, _dropout)
    
    # convolution layer2 
    conv2 = conv2d('conv2', norm1, _weights['wc2'], _biases['bc2'])
    # down sampling layer2
    pool2 = max_pool('pool2', conv2, k=2)
    # normalization layer2
    norm2 = norm('norm2', pool2, lsize=4)
    # Dropuout layer2
    norm2 = tf.nn.dropout(norm2, _dropout)
    
    # convolution layer3
    conv3 = conv2d('conv3', norm2, _weights['wc3'], _biases['bc3'])
    # down samling layer3
    pool3 = max_pool('pool3', conv3, k=2)
    # normalization layer3
    norm3 = norm('norm3', pool3, lsize=4)
    # Dropout layer3
    norm3 = tf.nn.dropout(norm3, _dropout)
    
    # Fully connected
    # transfer features into vector
    dense1 = tf.reshape(norm3, [-1, _weights['wd1'].get_shape().as_list()[0]])
    dense1 = tf.nn.relu(tf.matmul(dense1, _weights['wd1']) + _biases['bd1'], name='fc1')
    # fully connected
    dense2 = tf.nn.relu(tf.matmul(dense1, _weights['wd2']) + _biases['bd2'], name='fc2')
    
    # output
    out = tf.matmul(dense2, _weights['out']) + _biases['out']
    return out

# %%
# build the model
pred = alex_net(x, weights, biases, keep_prob)

# define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred, y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

init = tf.global_variables_initializer()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y, keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch accuracy
            acc = sess.run(accuracy, feed_dict={x: batch_x, y: batch_y, keep_prob: 1.})
            # Calculate batch loss
            loss = sess.run(cost, feed_dict={x: batch_x, y: batch_y, keep_prob: 1.})
            print ("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")
    print( "Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256], y: mnist.test.labels[:256], keep_prob: 1.}))
# Out:
# Iter 1280, Minibatch Loss= 179960.000000, Training Accuracy= 0.23438
# Iter 2560, Minibatch Loss= 108522.929688, Training Accuracy= 0.34375
# Iter 3840, Minibatch Loss= 79018.421875, Training Accuracy= 0.39062
# Iter 5120, Minibatch Loss= 61869.871094, Training Accuracy= 0.42188
# Iter 6400, Minibatch Loss= 55646.117188, Training Accuracy= 0.50000
# Iter 7680, Minibatch Loss= 38644.687500, Training Accuracy= 0.59375
# Iter 8960, Minibatch Loss= 33005.437500, Training Accuracy= 0.62500
# Iter 10240, Minibatch Loss= 20184.093750, Training Accuracy= 0.68750
# Iter 11520, Minibatch Loss= 16049.242188, Training Accuracy= 0.78125
# Iter 12800, Minibatch Loss= 32125.662109, Training Accuracy= 0.54688
# Iter 14080, Minibatch Loss= 22253.968750, Training Accuracy= 0.62500
# Iter 15360, Minibatch Loss= 18647.613281, Training Accuracy= 0.67188
# Iter 16640, Minibatch Loss= 16983.009766, Training Accuracy= 0.76562
# Iter 17920, Minibatch Loss= 15953.605469, Training Accuracy= 0.70312
# Iter 19200, Minibatch Loss= 14793.308594, Training Accuracy= 0.78125
# Iter 20480, Minibatch Loss= 16840.626953, Training Accuracy= 0.71875
# Iter 21760, Minibatch Loss= 14507.729492, Training Accuracy= 0.73438
# Iter 23040, Minibatch Loss= 16235.244141, Training Accuracy= 0.76562
# Iter 24320, Minibatch Loss= 14793.988281, Training Accuracy= 0.79688
# Iter 25600, Minibatch Loss= 12990.593750, Training Accuracy= 0.75000
# Iter 26880, Minibatch Loss= 15255.494141, Training Accuracy= 0.65625
# Iter 28160, Minibatch Loss= 10553.371094, Training Accuracy= 0.71875
# Iter 29440, Minibatch Loss= 21208.042969, Training Accuracy= 0.68750
# Iter 30720, Minibatch Loss= 7136.451172, Training Accuracy= 0.79688
# Iter 32000, Minibatch Loss= 13884.116211, Training Accuracy= 0.76562
# Iter 33280, Minibatch Loss= 9508.241211, Training Accuracy= 0.78125
# Iter 34560, Minibatch Loss= 16401.429688, Training Accuracy= 0.73438
# Iter 35840, Minibatch Loss= 6691.588867, Training Accuracy= 0.89062
# Iter 37120, Minibatch Loss= 16491.726562, Training Accuracy= 0.60938
# Iter 38400, Minibatch Loss= 11031.320312, Training Accuracy= 0.68750
# Iter 39680, Minibatch Loss= 13194.388672, Training Accuracy= 0.68750
# Iter 40960, Minibatch Loss= 11459.656250, Training Accuracy= 0.76562
# Iter 42240, Minibatch Loss= 14872.742188, Training Accuracy= 0.64062
# Iter 43520, Minibatch Loss= 10067.923828, Training Accuracy= 0.78125
# Iter 44800, Minibatch Loss= 15569.005859, Training Accuracy= 0.70312
# Iter 46080, Minibatch Loss= 13471.895508, Training Accuracy= 0.68750
# Iter 47360, Minibatch Loss= 5969.839844, Training Accuracy= 0.79688
# Iter 48640, Minibatch Loss= 4710.901367, Training Accuracy= 0.85938
# Iter 49920, Minibatch Loss= 8173.400391, Training Accuracy= 0.81250
# Iter 51200, Minibatch Loss= 9606.527344, Training Accuracy= 0.68750
# Iter 52480, Minibatch Loss= 4572.360352, Training Accuracy= 0.81250
# Iter 53760, Minibatch Loss= 5586.317871, Training Accuracy= 0.87500
# Iter 55040, Minibatch Loss= 14603.242188, Training Accuracy= 0.70312
# Iter 56320, Minibatch Loss= 7258.245605, Training Accuracy= 0.82812
# Iter 57600, Minibatch Loss= 1943.967285, Training Accuracy= 0.89062
# Iter 58880, Minibatch Loss= 6792.403809, Training Accuracy= 0.79688
# Iter 60160, Minibatch Loss= 9691.957031, Training Accuracy= 0.78125
# Iter 61440, Minibatch Loss= 13564.662109, Training Accuracy= 0.78125
# Iter 62720, Minibatch Loss= 7497.305664, Training Accuracy= 0.76562
# Iter 64000, Minibatch Loss= 10048.335938, Training Accuracy= 0.70312
# Iter 65280, Minibatch Loss= 8144.138672, Training Accuracy= 0.87500
# Iter 66560, Minibatch Loss= 7164.083984, Training Accuracy= 0.81250
# Iter 67840, Minibatch Loss= 5399.848145, Training Accuracy= 0.84375
# Iter 69120, Minibatch Loss= 1988.022949, Training Accuracy= 0.90625
# Iter 70400, Minibatch Loss= 7757.433105, Training Accuracy= 0.76562
# Iter 71680, Minibatch Loss= 6386.968750, Training Accuracy= 0.85938
# Iter 72960, Minibatch Loss= 7534.417480, Training Accuracy= 0.75000
# Iter 74240, Minibatch Loss= 5186.755859, Training Accuracy= 0.81250
# Iter 75520, Minibatch Loss= 8014.412109, Training Accuracy= 0.70312
# Iter 76800, Minibatch Loss= 1924.869385, Training Accuracy= 0.89062
# Iter 78080, Minibatch Loss= 5443.934570, Training Accuracy= 0.89062
# Iter 79360, Minibatch Loss= 5357.396484, Training Accuracy= 0.84375
# Iter 80640, Minibatch Loss= 4561.275391, Training Accuracy= 0.82812
# Iter 81920, Minibatch Loss= 7655.783203, Training Accuracy= 0.75000
# Iter 83200, Minibatch Loss= 8473.626953, Training Accuracy= 0.84375
# Iter 84480, Minibatch Loss= 6374.893555, Training Accuracy= 0.87500
# Iter 85760, Minibatch Loss= 2476.497070, Training Accuracy= 0.90625
# Iter 87040, Minibatch Loss= 3956.983887, Training Accuracy= 0.84375
# Iter 88320, Minibatch Loss= 1250.472656, Training Accuracy= 0.90625
# Iter 89600, Minibatch Loss= 2692.847412, Training Accuracy= 0.87500
# Iter 90880, Minibatch Loss= 4492.924805, Training Accuracy= 0.87500
# Iter 92160, Minibatch Loss= 6601.856445, Training Accuracy= 0.75000
# Iter 93440, Minibatch Loss= 3785.902100, Training Accuracy= 0.84375
# Iter 94720, Minibatch Loss= 1272.100708, Training Accuracy= 0.95312
# Iter 96000, Minibatch Loss= 6546.060547, Training Accuracy= 0.82812
# Iter 97280, Minibatch Loss= 6294.714844, Training Accuracy= 0.84375
# Iter 98560, Minibatch Loss= 5964.353516, Training Accuracy= 0.82812
# Iter 99840, Minibatch Loss= 7014.731934, Training Accuracy= 0.82812
# Iter 101120, Minibatch Loss= 5281.014648, Training Accuracy= 0.87500
# Iter 102400, Minibatch Loss= 3719.580078, Training Accuracy= 0.85938
# Iter 103680, Minibatch Loss= 1025.391968, Training Accuracy= 0.93750
# Iter 104960, Minibatch Loss= 3954.067383, Training Accuracy= 0.84375
# Iter 106240, Minibatch Loss= 2269.789551, Training Accuracy= 0.87500
# Iter 107520, Minibatch Loss= 1748.769531, Training Accuracy= 0.89062
# Iter 108800, Minibatch Loss= 1586.694458, Training Accuracy= 0.89062
# Iter 110080, Minibatch Loss= 3025.697754, Training Accuracy= 0.89062
# Iter 111360, Minibatch Loss= 711.331421, Training Accuracy= 0.93750
# Iter 112640, Minibatch Loss= 2838.871094, Training Accuracy= 0.87500
# Iter 113920, Minibatch Loss= 2110.606445, Training Accuracy= 0.89062
# Iter 115200, Minibatch Loss= 3243.305176, Training Accuracy= 0.82812
# Iter 116480, Minibatch Loss= 3085.794678, Training Accuracy= 0.89062
# Iter 117760, Minibatch Loss= 997.283569, Training Accuracy= 0.92188
# Iter 119040, Minibatch Loss= 1447.538086, Training Accuracy= 0.95312
# Iter 120320, Minibatch Loss= 3928.971680, Training Accuracy= 0.87500
# Iter 121600, Minibatch Loss= 1645.124390, Training Accuracy= 0.92188
# Iter 122880, Minibatch Loss= 695.542847, Training Accuracy= 0.95312
# Iter 124160, Minibatch Loss= 3927.874512, Training Accuracy= 0.89062
# Iter 125440, Minibatch Loss= 4995.045898, Training Accuracy= 0.87500
# Iter 126720, Minibatch Loss= 2531.450928, Training Accuracy= 0.89062
# Iter 128000, Minibatch Loss= 1316.125488, Training Accuracy= 0.90625
# Iter 129280, Minibatch Loss= 2280.461914, Training Accuracy= 0.90625
# Iter 130560, Minibatch Loss= 865.794922, Training Accuracy= 0.92188
# Iter 131840, Minibatch Loss= 2678.476074, Training Accuracy= 0.89062
# Iter 133120, Minibatch Loss= 3459.702148, Training Accuracy= 0.90625
# Iter 134400, Minibatch Loss= 3907.664795, Training Accuracy= 0.87500
# Iter 135680, Minibatch Loss= 2484.699951, Training Accuracy= 0.95312
# Iter 136960, Minibatch Loss= 1516.711670, Training Accuracy= 0.95312
# Iter 138240, Minibatch Loss= 3016.695557, Training Accuracy= 0.92188
# Iter 139520, Minibatch Loss= 2673.337891, Training Accuracy= 0.92188
# Iter 140800, Minibatch Loss= 459.545044, Training Accuracy= 0.95312
# Iter 142080, Minibatch Loss= 4080.276855, Training Accuracy= 0.89062
# Iter 143360, Minibatch Loss= 3158.733154, Training Accuracy= 0.87500
# Iter 144640, Minibatch Loss= 2624.442871, Training Accuracy= 0.89062
# Iter 145920, Minibatch Loss= 305.038330, Training Accuracy= 0.95312
# Iter 147200, Minibatch Loss= 2502.354248, Training Accuracy= 0.87500
# Iter 148480, Minibatch Loss= 3642.714844, Training Accuracy= 0.89062
# Iter 149760, Minibatch Loss= 3459.079102, Training Accuracy= 0.87500
# Iter 151040, Minibatch Loss= 1636.197388, Training Accuracy= 0.90625
# Iter 152320, Minibatch Loss= 1694.383057, Training Accuracy= 0.93750
# Iter 153600, Minibatch Loss= 2929.153320, Training Accuracy= 0.90625
# Iter 154880, Minibatch Loss= 1760.736938, Training Accuracy= 0.92188
# Iter 156160, Minibatch Loss= 2642.285645, Training Accuracy= 0.87500
# Iter 157440, Minibatch Loss= 1166.851318, Training Accuracy= 0.90625
# Iter 158720, Minibatch Loss= 3076.560059, Training Accuracy= 0.87500
# Iter 160000, Minibatch Loss= 1464.305420, Training Accuracy= 0.92188
# Iter 161280, Minibatch Loss= 745.504272, Training Accuracy= 0.96875
# Iter 162560, Minibatch Loss= 3240.028320, Training Accuracy= 0.90625
# Iter 163840, Minibatch Loss= 2477.177490, Training Accuracy= 0.89062
# Iter 165120, Minibatch Loss= 2313.549316, Training Accuracy= 0.87500
# Iter 166400, Minibatch Loss= 3435.085205, Training Accuracy= 0.85938
# Iter 167680, Minibatch Loss= 1042.195312, Training Accuracy= 0.96875
# Iter 168960, Minibatch Loss= 1667.503174, Training Accuracy= 0.93750
# Iter 170240, Minibatch Loss= 2071.764648, Training Accuracy= 0.90625
# Iter 171520, Minibatch Loss= 1949.848999, Training Accuracy= 0.84375
# Iter 172800, Minibatch Loss= 3272.887207, Training Accuracy= 0.92188
# Iter 174080, Minibatch Loss= 1539.845703, Training Accuracy= 0.92188
# Iter 175360, Minibatch Loss= 702.045166, Training Accuracy= 0.93750
# Iter 176640, Minibatch Loss= 626.610229, Training Accuracy= 0.95312
# Iter 177920, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 179200, Minibatch Loss= 1004.131287, Training Accuracy= 0.95312
# Iter 180480, Minibatch Loss= 1729.625977, Training Accuracy= 0.90625
# Iter 181760, Minibatch Loss= 3676.934082, Training Accuracy= 0.84375
# Iter 183040, Minibatch Loss= 1306.130127, Training Accuracy= 0.93750
# Iter 184320, Minibatch Loss= 1188.561279, Training Accuracy= 0.92188
# Iter 185600, Minibatch Loss= 1389.973511, Training Accuracy= 0.96875
# Iter 186880, Minibatch Loss= 1495.627441, Training Accuracy= 0.93750
# Iter 188160, Minibatch Loss= 1189.154785, Training Accuracy= 0.92188
# Iter 189440, Minibatch Loss= 119.692871, Training Accuracy= 0.96875
# Iter 190720, Minibatch Loss= 2376.691650, Training Accuracy= 0.93750
# Iter 192000, Minibatch Loss= 1249.952148, Training Accuracy= 0.98438
# Iter 193280, Minibatch Loss= 1003.799927, Training Accuracy= 0.93750
# Iter 194560, Minibatch Loss= 1156.311768, Training Accuracy= 0.90625
# Iter 195840, Minibatch Loss= 756.435974, Training Accuracy= 0.95312
# Iter 197120, Minibatch Loss= 943.379822, Training Accuracy= 0.92188
# Iter 198400, Minibatch Loss= 1732.668945, Training Accuracy= 0.92188
# Iter 199680, Minibatch Loss= 984.359558, Training Accuracy= 0.92188
# Optimization Finished!
# Testing Accuracy: 0.9375
